# %%
import pandas as pd

# %%
df = pd.read_excel(r'datasets\final_depression_dataset_1.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_excel(r'datasets\final_depression_dataset_1.xlsx')
#
# File c:\Users\danis\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
# ...

# %%
df = df[df['Working Professional or Student'].str.lower() == 'student']

# %%
df = df.drop(columns='Profession', axis=1)

# %%
df.rename(columns={'Working Professional or Student': 'Profession'}, inplace=True)

# %%
df.to_excel(r'datasets\final_depression_dataset_2.xlsx', index=False)

# %%
df2 = pd.read_excel(r'datasets\student_depression_dataset.xlsx')

# %%
df2.head()
# Out:
#    Gender  Age           City Profession  Academic Pressure  Work Pressure  \
# 0    Male   33  Visakhapatnam    Student                  5              0
# 1  Female   24      Bangalore    Student                  2              0
# 2    Male   31       Srinagar    Student                  3              0
# 3  Female   28       Varanasi    Student                  3              0
# 4  Female   25         Jaipur    Student                  4              0
#
#    CGPA  Study Satisfaction  Job Satisfaction       Sleep Duration  \
# 0  8.97                   2                 0          '5-6 hours'
# 1  5.90                   5                 0          '5-6 hours'
# 2  7.03                   5                 0  'Less than 5 hours'
# 3  5.59                   2                 0          '7-8 hours'
# 4  8.13                   3                 0          '5-6 hours'
#
#   Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# ...

# %%
df = df[df2.columns]

# %%
combined_df = pd.concat([df,df2] , ignore_index=True)

# %%
combined_df.to_excel('combined_students_data.xlsx', index=False)

# %%
combined_df.isnull().sum()
# Out:
# Gender                                     0
# Age                                        0
# City                                       0
# Profession                                 0
# Academic Pressure                          0
# Work Pressure                            502
# CGPA                                       0
# Study Satisfaction                         0
# Job Satisfaction                         502
# Sleep Duration                             0
# Dietary Habits                             0
# Degree                                     0
# Have you ever had suicidal thoughts ?      0
# Work/Study Hours                           0
# Financial Stress                           0
# Family History of Mental Illness           0
# Depression                                 0
# dtype: int64

# %%
combined_df['Have you ever had suicidal thoughts ?'].value_counts()
# Out:
# Have you ever had suicidal thoughts ?
# Yes    17916
# No     10487
# Name: count, dtype: int64

# %%
print(type(combined_df))
# Out:
# <class 'NoneType'>

# %%
combined_df = combined_df.drop(['Work Pressure', 'Job Satisfaction'], axis=1)

# %%
import pandas as pd
combined_df = pd.read_excel(r'datasets\combined_students_data.xlsx')

# %%
combined_df['Have you ever had suicidal thoughts ?'].value_counts()
# Out:
# Have you ever had suicidal thoughts ?
# 1    17916
# 0    10487
# Name: count, dtype: int64

# %%
combined_df['Dietary Habits'] = combined_df['Dietary Habits'].map({
    'Healthy': 2,
    'Moderate': 1,
    'Unhealthy': 0
})

# %%
combined_df
# Out:
#       Gender  Age       City  Academic Pressure  CGPA  Study Satisfaction  \
# 0          M   28   Varanasi                  2  6.51                   4
# 1          M   28  Bangalore                  4  7.48                   5
# 2          M   25     Rajkot                  1  7.21                   3
# 3          M   23     Mumbai                  1  9.90                   4
# 4          F   31   Vadodara                  1  5.97                   5
# ...      ...  ...        ...                ...   ...                 ...
# 28398      F   27      Surat                  5  5.75                   5
# 28399      M   27   Ludhiana                  2  9.40                   3
# 28400      M   31  Faridabad                  3  6.61                   4
# 28401      F   18   Ludhiana                  5  6.88                   2
# 28402      M   27      Patna                  4  9.24                   1
#
#        Sleep Duration Unnamed: 7      Degree  \
# ...

# %%
combined_df[combined_df['Age'] < 27]
# Out:
#       Gender  Age       City  Academic Pressure  CGPA  Study Satisfaction  \
# 2          M   25     Rajkot                  1  7.21                   3
# 3          M   23     Mumbai                  1  9.90                   4
# 5          M   19     Rajkot                  4  9.05                   4
# 7          F   20       Pune                  4  6.17                   1
# 11         M   24  Bangalore                  2  9.79                   1
# ...      ...  ...        ...                ...   ...                 ...
# 28390      M   19    Kolkata                  4  7.13                   1
# 28394      F   20     Indore                  3  7.72                   5
# 28395      F   24  Hyderabad                  3  6.02                   2
# 28396      M   23   Srinagar                  3  6.00                   2
# 28401      F   18   Ludhiana                  5  6.88                   2
#
#        Sleep Duration Unnamed: 7      Degree  \
# ...

# %%
combined_df['City'].value_counts()
# Out:
# City
# Kalyan                  1593
# Srinagar                1400
# Hyderabad               1363
# Vasai-Virar             1312
# Lucknow                 1174
# Thane                   1157
# Ludhiana                1128
# Agra                    1113
# Surat                   1097
# Kolkata                 1082
# Jaipur                  1056
# Patna                   1024
# Pune                     986
# Visakhapatnam            985
# Ahmedabad                964
# Bhopal                   954
# Chennai                  903
# Meerut                   841
# Rajkot                   831
# Delhi                    784
# Bangalore                783
# Ghaziabad                759
# Mumbai                   712
# Vadodara                 707
# Varanasi                 698
# Nagpur                   665
# Indore                   652
# Kanpur                   621
# Nashik                   562
# Faridabad                471
# Bhavna                     2
# City                       2
# ...

# %%
# ...existing code...

combined_df = combined_df[combined_df['Age'] < 28]
# ...existing code...

# %%
combined_df['Age'].value_counts()
# Out:
# Age
# 24    2295
# 20    2274
# 25    1813
# 21    1755
# 23    1669
# 18    1611
# 19    1586
# 27    1488
# 22    1183
# 26    1177
# Name: count, dtype: int64

# %%
# ...existing code...

city_counts = combined_df['City'].value_counts()
combined_df = combined_df[combined_df['City'].isin(city_counts[city_counts >= 20].index)]
# ...existing code...

# %%
combined_df['City'].value_counts()
# Out:
# City
# Kalyan           947
# Hyderabad        846
# Srinagar         780
# Vasai-Virar      761
# Agra             729
# Thane            718
# Ludhiana         685
# Lucknow          672
# Surat            672
# Jaipur           635
# Ahmedabad        631
# Kolkata          622
# Pune             601
# Bhopal           597
# Chennai          577
# Visakhapatnam    554
# Bangalore        520
# Rajkot           519
# Patna            510
# Delhi            470
# Meerut           456
# Ghaziabad        434
# Mumbai           429
# Indore           421
# Nagpur           393
# Vadodara         380
# Kanpur           357
# Nashik           326
# Varanasi         323
# Faridabad        273
# Name: count, dtype: int64

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16838 entries, 2 to 28402
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 16838 non-null  object
#  1   Age                                    16838 non-null  int64
#  2   City                                   16838 non-null  object
#  3   Academic Pressure                      16838 non-null  int64
#  4   CGPA                                   16838 non-null  float64
#  5   Study Satisfaction                     16838 non-null  int64
#  6   Sleep Duration                         16838 non-null  float64
#  7   Unnamed: 7                             16838 non-null  object
#  8   Degree                                 16838 non-null  object
#  9   Have you ever had suicidal thoughts ?  16838 non-null  int64
# ...

# %%
combined_df
# Out:
#       Gender  Age       City  Academic Pressure  CGPA  Study Satisfaction  \
# 2          M   25     Rajkot                  1  7.21                   3
# 3          M   23     Mumbai                  1  9.90                   4
# 5          M   19     Rajkot                  4  9.05                   4
# 7          F   20       Pune                  4  6.17                   1
# 11         M   24  Bangalore                  2  9.79                   1
# ...      ...  ...        ...                ...   ...                 ...
# 28396      M   23   Srinagar                  3  6.00                   2
# 28398      F   27      Surat                  5  5.75                   5
# 28399      M   27   Ludhiana                  2  9.40                   3
# 28401      F   18   Ludhiana                  5  6.88                   2
# 28402      M   27      Patna                  4  9.24                   1
#
#        Sleep Duration Unnamed: 7      Degree  \
# ...

# %%
# ...existing code...

combined_df.rename(columns={'Unnamed: 7': 'Dietary Habits'}, inplace=True)
# ...existing code...

# %%
combined_df
# Out:
#       Gender  Age       City  Academic Pressure  CGPA  Study Satisfaction  \
# 2          M   25     Rajkot                  1  7.21                   3
# 3          M   23     Mumbai                  1  9.90                   4
# 5          M   19     Rajkot                  4  9.05                   4
# 7          F   20       Pune                  4  6.17                   1
# 11         M   24  Bangalore                  2  9.79                   1
# ...      ...  ...        ...                ...   ...                 ...
# 28396      M   23   Srinagar                  3  6.00                   2
# 28398      F   27      Surat                  5  5.75                   5
# 28399      M   27   Ludhiana                  2  9.40                   3
# 28401      F   18   Ludhiana                  5  6.88                   2
# 28402      M   27      Patna                  4  9.24                   1
#
#        Sleep Duration Dietary Habits      Degree  \
# ...

# %%
combined_df.to_excel(r'datasets\Ready_Dataset.xlsx', index=False)

# %%
combined_df.columns
# Out:
# Index(['Gender', 'Age', 'City', 'Academic Pressure', 'CGPA',
#        'Study Satisfaction', 'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')
